# %%
import pandas as pd
import logging

# %%
input_file = r"D:\Data\01_Projects\Active\publipostage_doeth\data\input\Liste des BOETH par RGP CLI avec adresses V2.xlsx"
sheet_name = "Liste des BOETH par RGP CLI ave"
df = pd.read_excel(input_file, sheet_name=sheet_name)
df.head()
# Out:
#   CODE_REGROUPEMENT REGROUPEMENT      SIREN  NIC                NOM_CLIENT  \
# 0           ADAPE01       ADAPEI  775590920  671  ADAPEI 35 - IME L'ETOILE
# 1           ADAPE01       ADAPEI  775590920  689  CENTRE DE SERVICES VITRE
# 2           ADAPE01       ADAPEI  775590920  739        ADAPEI 35 MOINERIE
# 3           AGRIA02       AGRIAL  311623987   22          BRIENT MORDELLES
# 4           AGRIA02       AGRIAL  311623987   22          BRIENT MORDELLES
#
#           ADRESSE_CLIENT CP_CLIENT VILLE_CLIENT    APE        NOM  \
# 0   29 RUE DE BEAUVAIS       35500        VITRE  8710B   BOUCAULT
# 1            7 DU MAIL       35500        VITRE  8720A   BOUCAULT
# 2  19 RUE DE LA JANAIE       35400   SAINT-MALO  8810C    TEMPIER
# 3       2 RUE DE VINCE       35310    MORDELLES  1013A     DIALLO
# 4       2 RUE DE VINCE       35310    MORDELLES  1013A  GUEZENNEC
#
#             PRENOM       DATE_NAISSANCE   ANNEE  \
# 0     MARIE FRANCE  1970-08-10 00:00:00  2025.0
# ...

# %%
# Recherche des informations sur BOUCAULT	MARIE FRANCE
df[(df['NOM'] == 'BOUCAULT') & (df['PRENOM'] == 'MARIE FRANCE')].head()
# Out:
#   CODE_REGROUPEMENT REGROUPEMENT      SIREN  NIC                NOM_CLIENT  \
# 0           ADAPE01       ADAPEI  775590920  671  ADAPEI 35 - IME L'ETOILE
# 1           ADAPE01       ADAPEI  775590920  689  CENTRE DE SERVICES VITRE
#
#          ADRESSE_CLIENT CP_CLIENT VILLE_CLIENT    APE       NOM        PRENOM  \
# 0  29 RUE DE BEAUVAIS       35500        VITRE  8710B  BOUCAULT  MARIE FRANCE
# 1           7 DU MAIL       35500        VITRE  8720A  BOUCAULT  MARIE FRANCE
#
#         DATE_NAISSANCE   ANNEE QUALIFICATION ETP_MAJORE  ETP_ANNUEL  NB_HEURES
# 0  1970-08-10 00:00:00  2025.0    SECRETAIRE        oui    0.115382      140.0
# 1  1970-08-10 00:00:00  2025.0    SECRETAIRE        oui    0.011538       14.0
